# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/beatrizpereira/Desktop/Python_study/projetinho/aula1.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/beatrizpereira/Desktop/Python_study/projetinho/aula1.ipynb#ch0000000?line=0'>1</a> import pandas as pd
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/__init__.py:135, in <module>
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/__init__.py?line=116'>117</a> from pandas.core.computation.api import eval
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/__init__.py?line=118'>119</a> from pandas.core.reshape.api import (
# ...
