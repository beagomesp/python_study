# %%
import pandas as pd
df = pd.read_excel("Clientes.xlsx")

# %%
df.sort_values(by="Nome")
# Out:
#    ID Entidade Tipo     Nome  Idade Genero  Sobrenome            Email  \
# 0            1   EA      Bea     25      F      Gomes  email@email.com
# 4            5   EP   Bianca     23      F      Gomes  email@email.com
# 1            2   EP  Fhelipe     24      M  Rodrigues  email@email.com
# 2            3   EA    Tania     24      F     Arruda  email@email.com
# 3            4   EP  Weslley     23      M   Ferreira  email@email.com
#
#    Pontos  Teste
# 0      45      0
# 4      29      0
# 1      28      0
# 2      45      0
# 3      35      0

# %%
df.sort_values("Nome", ascending= False)
# Out:
#    ID Entidade Tipo     Nome  Idade Genero  Sobrenome            Email  \
# 3            4   EP  Weslley     23      M   Ferreira  email@email.com
# 2            3   EA    Tania     24      F     Arruda  email@email.com
# 1            2   EP  Fhelipe     24      M  Rodrigues  email@email.com
# 4            5   EP   Bianca     23      F      Gomes  email@email.com
# 0            1   EA      Bea     25      F      Gomes  email@email.com
#
#    Pontos  Teste
# 3      35      0
# 2      45      0
# 1      28      0
# 4      29      0
# 0      45      0

# %%
df.sort_values(["Nome","Sobrenome"], inplace= True)

# %%
#df[["Nome","Sobrenome"]]
df.filter(items = ['Nome','Sobrenome'])
# Out:
#       Nome  Sobrenome
# 0      Bea      Gomes
# 4   Bianca      Gomes
# 1  Fhelipe  Rodrigues
# 2    Tania     Arruda
# 3  Weslley   Ferreira

# %%
df.sort_values(["Nome","Sobrenome"], ascending = False).loc[(df.Pontos>20)]
# Out:
#    ID Entidade Tipo     Nome  Idade Genero  Sobrenome            Email  \
# 3            4   EP  Weslley     23      M   Ferreira  email@email.com
# 2            3   EA    Tania     24      F     Arruda  email@email.com
# 1            2   EP  Fhelipe     24      M  Rodrigues  email@email.com
# 4            5   EP   Bianca     23      F      Gomes  email@email.com
# 0            1   EA      Bea     25      F      Gomes  email@email.com
#
#    Pontos  Teste
# 3      35      0
# 2      45      0
# 1      28      0
# 4      29      0
# 0      45      0

# %%
#df.filter(like = "en")
df.filter(regex=".en.")

# %%
df.head()
# Out:
#    ID Entidade Tipo     Nome  Idade Genero  Sobrenome            Email  \
# 0            1   EA      Bea     25      F      Gomes  email@email.com
# 1            2   EP  Fhelipe     24      M  Rodrigues  email@email.com
# 2            3   EA    Tania     24      F     Arruda  email@email.com
# 3            4   EP  Weslley     23      M   Ferreira  email@email.com
# 4            5   EP   Bianca     23      F      Gomes  email@email.com
#
#    Pontos  Teste
# 0      45      0
# 1      28      0
# 2      45      0
# 3      35      0
# 4      29      0
